# %% [markdown]
# # Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
import warnings as warn
warn.filterwarnings("ignore")

# %% [markdown]
# # Import the dataset from the AutoMPG dataset file. Assign it to a variable called mpg_df

# %%
mpg_df = pd.read_csv("auto-mpg.csv")
mpg_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# # Perform basic EDA to understand the structure of the data

# %%
mpg_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mpg_df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
mpg_df.shape
# Out:
# (398, 9)

# %%
mpg_df.info
# Out:
# <bound method DataFrame.info of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]>

# %%
mpg_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %% [markdown]
# # Check and handle the missing values, if any.

# %%
mpg_df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# # Create a plot to check the relationship between horsepower and acceleration. Note down your insight for the same. Beautify the graph using various customizations.

# %%
mpg_df['horsepower'].replace('?', float('nan'), inplace=True)
mpg_df['horsepower']=pd.to_numeric(mpg_df['horsepower'])
mpg_df.dtypes
# Plotting
sns.relplot(x='horsepower',y='acceleration',data=mpg_df,palette=['red'])
plt.show()

##Insights
# On increasing the horsepower, acceleration decreases

# %%
# sns.catplot(x="acceleration",hue="horsepower",data=mpg_df,kind="strip")
# plt.show()

# %%
# sns.boxplot(x="acceleration",y="horsepower",data=mpg_df)
# sns.set(rc={"figure.figsize":(30, 90)})
# plt.show()

# %%
# sns.stripplot(y="horsepower",x="acceleration",data=mpg_df)
# plt.show()

# %% [markdown]
# # Generate subplots to display the histograms for acceleration, displacement and weight and kilometer_per_litre. Note down your insight for the same

# %%
# # plt.subplot(1,3,1)
# plt.hist(mpg_df['acceleration'],color="pink")
# plt.show()

# # plt.subplot(1,3,2)
# plt.hist(mpg_df['displacement'],color="lightblue")
# plt.show()

# # plt.subplot(1,3,3)
# plt.hist(mpg_df['weight'],color="peachpuff")
# plt.show()

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 8))

sns.histplot(mpg_df['acceleration'], ax=axes[0], color='red')
axes[0].set_xlabel('Acceleration')

sns.histplot(mpg_df['displacement'], ax=axes[1], color='green')
axes[ 1].set_xlabel('Displacement')

sns.histplot(mpg_df['weight'], ax=axes[2], color='blue')
axes[ 2].set_xlabel('Weight')

mpg_df['km_per_ltr']=mpg_df['mpg'] * 0.425144

sns.histplot(mpg_df['km_per_ltr'], ax=axes[3], color='yellow')
axes[ 3].set_xlabel('km_per_ltr')

plt.tight_layout()

plt.show()
# print(mpg_df['kilometer_per_litre'])

# insights
# acceleration count is increasing until 15, then descreases
# displacement count is decreases until 200, then slowly descreases
# weight count is increasing sharply at 2000, then descreases
# MPG count is sharp increasing until 20, then descreases

# %% [markdown]
# # Create a plot to check the relationship between displacement and weight for origin 2, color the datapoints based on no of cylinders. Note down your insight for the same and save the plot as an image file.

# %%
myplot=sns.relplot(x='displacement', y='weight', hue='cylinders', data=mpg_df[(mpg_df.origin==2)] ,palette="Set2")
# myplot2=sns.relplot(x='displacement', y='weight', hue='cylinders', data=mpg_df ,palette="Set2", col="origin")
plt.show()
# fig = myplot.get_figure()
# fig = myplot
myplot.savefig("myplot.png")

## Insights
# Overall insights: More the displacement, more the weight 
# The displacement lies between 60 to 150  for 4 cylinders
# The displacement lies between 120 to 130 for 5 cylinders
# The displacement lies between 160 to 170 for 6 cylinders

# %% [markdown]
# # Display the frequency distribution of the Origin variable. Note down your insight for the same

# %%
# plt.hist(mpg_df['origin'], color="plum")
# plt.show()
# sns.histplot(x='origin',data=mpg_df, color="plum")
# plt.show()

# %%
sns.countplot(x='origin',data=mpg_df,palette='Set2')
plt.show()

#insight
# for Origin 1 count is 250 
# for Origin 2 count is 70
# for Origin 3 count is 80

# %% [markdown]
# # Check the relationship of multiple variables wrt kilometer_per_litre. Note down your insight for the same

# %%
sns.pairplot(mpg_df, y_vars=["km_per_ltr"])
plt.show()

# %% [markdown]
# # Display the average weight based on no of cylinders present. Note down the insight for the same

# %%
avg_df=mpg_df.groupby('cylinders')['weight'].mean().reset_index()
print(avg_df)
sns.barplot(data=avg_df,x='cylinders',y='weight',palette='Set2')
plt.title("Average Weight based on Number of Cylinders", fontsize=7) 
plt.xlabel("Number of Cylinders", fontsize=7)
plt.ylabel("Average Weight", fontsize=7)
plt.show()
# Out:
#    cylinders       weight
# 0          3  2398.500000
# 1          4  2308.127451
# 2          5  3103.333333
# 3          6  3198.226190
# 4          8  4114.718447

# %% [markdown]
# # Check for the outliers in the dataset. Note down the insight for the same.

# %%
# sns.displot(data=mpg_df, palette="tab10")
plt.figure(figsize=(10, 8))
sns.boxplot(data=mpg_df, orient='v', palette='Set2')  
plt.show()

#insights
# for displacement outlier values are below 50 and above 500
# for weights outlier values are below 1500 and above are 5200
# and so on for others

# %%
# sns.stripplot(data=mpg_df)

# %% [markdown]
# # Plot the correlations for variables.

# %%
# plt.figure(figsize=(14,8))
# corr=mpg_df.corr()
# sns.heatmap(corr,annot=True)

# %%
plt.figure(figsize=(14,8))
corr=mpg_df.corr()
sns.heatmap(corr,annot=True,cmap="Blues", fmt='.3g')
# Out:
# <Axes: >
